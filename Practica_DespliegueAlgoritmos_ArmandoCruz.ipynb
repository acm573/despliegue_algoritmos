# %% [markdown]
# # Práctica Final: detección de mensajes troll
#
# En los últimos años Twitch se ha consolidad como uno de los principales medios de comunicación especialmente para las generaciones más jóvenes.
#
# Al tratarse de una plataforma participativa en la que los usuarios pueden poner comentarios durante y posteriormente a las emisiones. Entre estos comentarios han aparecido como siempre comentarios ofensisvos.
#
# En esta práctica construiremos una Inteligencia Artificial capaz de clasificar esos mensajes troll.
#
# Durante la práctica entrenaremos el modelo de Deep Learning y lo desplegaremos para inferencia en batch, la más habitual actualmente dentro de la industria:

# %% [markdown]
# ## Teoría
#
# 1. ¿Qué es Apache Beam?
# 2. ¿Cuáles son las diferentes formas de desplegar un modelo?
# 3. ¿Cuál es la principal diferencia entre la inferencia en batch y la inferencia en streaming?

# %% [markdown]
# **Respuestas**
#
# 1.- Es un marco de programación open source para procesar datos de manera eficiente en lotes y en streaming. Permite crear pipelines de procesamiento de datos que pueden ejecutarse en diferentes sistemas de ejecución, como Apache Flink, Apache Spark y Google Cloud Dataflow. Su ventaja principal es el unificar el procesamiento por lotes y en tiempo real en una API, simplificando el desarrollo y gestión de aplicaciones de procesamiento de datos.
#
# 2.- Las formas de desplegar un modelo son: batch y on demand.
#
# 3.- La inferencia batch procesa conjuntos de datos completos y se pueden generar predicciones para todos los datos al mismo tiempo. Por el contrario, la inferencia en streamming es un procesamiento y predicción al tiempo que se reciben los datos. Esto es muy útil en datos que fluyen en tiempo real.

# %% [markdown]
# # Configuración de nuestro proyecto en GCP

# %%
PROJECT_ID = "serious-studio-380614" #@param {type:"string"}
! gcloud config set project $PROJECT_ID
# Out:
# Updated property [core/project].

# %%
import sys

# If you are running this notebook in Colab, run this cell and follow the
# instructions to authenticate your GCP account. This provides access to your
# Cloud Storage bucket and lets you submit training jobs and prediction
# requests.

if 'google.colab' in sys.modules:
  from google.colab import auth as google_auth
  google_auth.authenticate_user()

# If you are running this notebook locally, replace the string below with the
# path to your service account key and run this cell to authenticate your GCP
# account.
else:
  # %env GOOGLE_APPLICATION_CREDENTIALS ''

# %% [markdown]
# Creamos el bucket mediante la consola y una vez creado lo indicamos en la variable:

# %%
BUCKET_NAME = "produccionkc" #@param {type:"string"}
REGION = "europe-west1" #@param {type:"string"}

# %%
! gsutil ls -al gs://$BUCKET_NAME
# Out:
#                                  gs://produccionkc/twitter-sentiment-batch/

# %% [markdown]
# # Entrenamiento e inferencia en Batch
#
# ## Preparación
#
# Para esta primera parte se va a utilizar [Tweets Dataset for Detection of Cyber-Trolls](https://www.kaggle.com/dataturks/dataset-for-detection-of-cybertrolls). El objetivo es desarrollar un clasificador binario para detectar si el mensaje recibido es troll (1) o no (0). **Las métricas obtenidas del entrenamiento y la inferencia no se tendrán en cuenta para la evaluación de la práctica, la importancia está en la arquitectura de la solución**, es decir, lo importante no es que nuestro modelo detecte correctamente los tweets de trolls si no que funcione y sea capaz de hacer inferencias.

# %% [markdown]
# A continuación, se van a subir los datos de entrenamiento al bucket del proyecto que se haya creado. **Importante:** crea el bucket en una única región. Os dejo disponibilizado el dataset en un bucket de acceso público:

# %%
# Upload data to your bucket
! wget https://storage.googleapis.com/datos-practica-compartidos/Dataset%20for%20Detection%20of%20Cyber-Trolls.json -O - | gsutil cp - gs://$BUCKET_NAME/data.json
# Out:
# --2023-03-19 20:36:31--  https://storage.googleapis.com/datos-practica-compartidos/Dataset%20for%20Detection%20of%20Cyber-Trolls.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.127.128, 142.250.145.128, 2a00:1450:4013:c14::80, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.127.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2756023 (2.6M) [application/json]
# Saving to: ‘STDOUT’
#
# -                     0%[                    ]       0  --.-KB/s               Copying from <STDIN>...
# -                   100%[===================>]   2.63M   926KB/s    in 2.9s
#
# 2023-03-19 20:36:34 (926 KB/s) - written to stdout [2756023/2756023]
#
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.

# %% [markdown]
# Ahora se crea el directorio dónde vas a desarrollar esta primera parte de la práctica.

# %%
# %mkdir /content/batch

# %% [markdown]
# Se establece el directorio de trabajo que hemos creado.

# %%
import os

# Set the working directory to the sample code directory
# %cd /content/batch

WORK_DIR = os.getcwd()
# Out:
# /content/batch

# %% [markdown]
# Ahora se descargarán los datos en el workspace de Colab para trabajar en local.

# %%
! wget https://storage.googleapis.com/datos-practica-compartidos/Dataset%20for%20Detection%20of%20Cyber-Trolls.json
# Out:
# --2023-03-19 20:38:21--  https://storage.googleapis.com/datos-practica-compartidos/Dataset%20for%20Detection%20of%20Cyber-Trolls.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.153.128, 142.250.145.128, 108.177.119.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.153.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2756023 (2.6M) [application/json]
# Saving to: ‘Dataset for Detection of Cyber-Trolls.json’
#
# Dataset for Detecti 100%[===================>]   2.63M  --.-KB/s    in 0.01s
#
# 2023-03-19 20:38:22 (200 MB/s) - ‘Dataset for Detection of Cyber-Trolls.json’ saved [2756023/2756023]

# %% [markdown]
# Se establecen las dependencias que se usarán en la práctica. Se pueden añadir y quitar las dependencias que no se usen o viceversa.

# %%
# %%writefile requirements.txt
#
# apache-beam[gcp]
# tensorflow
# gensim
# fsspec
# gcsfs
# numpy
# nltk
# Out:
# Writing requirements.txt

# %% [markdown]
# Instalamos las dependencias. **No olvides reiniciar el entorno al instalar y establecer las variables y credenciales de GCP al arrancar.**

# %%
! pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: apache-beam[gcp] in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (2.46.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (2.11.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 5)) (2023.3.0)
# Requirement already satisfied: gcsfs in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (2023.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (1.22.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2022.7.1)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: httplib2<0.22.0,>=0.8 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (0.3.1.1)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.51.3)
# Requirement already satisfied: protobuf<4,>3.12.2 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (3.19.6)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.22.2)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (0.18)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (3.13.0)
# Requirement already satisfied: orjson<4.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (3.8.7)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (4.5.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.7)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.7.3)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2022.10.31)
# Requirement already satisfied: pyarrow<10.0.0,>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (9.0.0)
# Requirement already satisfied: google-cloud-core<3,>=0.28.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2.3.2)
# Requirement already satisfied: google-cloud-recommendations-ai<0.8.0,>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: google-cloud-language<2,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: google-cloud-bigquery<4,>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (3.12.0)
# Requirement already satisfied: google-cloud-videointelligence<2,>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: google-auth-httplib2<0.2.0,>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (0.1.0)
# Requirement already satisfied: google-cloud-bigquery-storage<2.17,>=2.6.3 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2.16.2)
# Requirement already satisfied: google-cloud-bigtable<2,>=0.31.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.7.3)
# Requirement already satisfied: google-cloud-datastore<2,>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (1.15.5)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (3.28.0)
# Requirement already satisfied: cachetools<5,>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (4.2.4)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2.16.2)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (2.15.1)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /usr/local/lib/python3.9/dist-packages (from apache-beam[gcp]->-r requirements.txt (line 2)) (0.5.31)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (63.4.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (23.3.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (15.0.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (2.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (23.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (0.31.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (3.8.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (2.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow->-r requirements.txt (line 3)) (3.3.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.9/dist-packages (from gensim->-r requirements.txt (line 4)) (1.10.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.9/dist-packages (from gensim->-r requirements.txt (line 4)) (6.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.9/dist-packages (from gcsfs->-r requirements.txt (line 6)) (3.8.4)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.9/dist-packages (from gcsfs->-r requirements.txt (line 6)) (4.4.2)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.9/dist-packages (from gcsfs->-r requirements.txt (line 6)) (2.7.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.9/dist-packages (from gcsfs->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->-r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->-r requirements.txt (line 8)) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk->-r requirements.txt (line 8)) (4.65.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->-r requirements.txt (line 6)) (2.0.12)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->-r requirements.txt (line 6)) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->-r requirements.txt (line 6)) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->-r requirements.txt (line 6)) (22.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->-r requirements.txt (line 6)) (4.0.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 3)) (0.40.0)
# Requirement already satisfied: oauth2client>=1.4.12 in /usr/local/lib/python3.9/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]->-r requirements.txt (line 2)) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]->-r requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]->-r requirements.txt (line 2)) (4.9)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.9/dist-packages (from google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]->-r requirements.txt (line 2)) (2.11.0)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]->-r requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: grpc-google-iam-v1<0.13dev,>=0.12.3 in /usr/local/lib/python3.9/dist-packages (from google-cloud-bigtable<2,>=0.31.1->apache-beam[gcp]->-r requirements.txt (line 2)) (0.12.6)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.9/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]->-r requirements.txt (line 2)) (1.48.2)
# Requirement already satisfied: overrides<7.0.0,>=6.0.1 in /usr/local/lib/python3.9/dist-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]->-r requirements.txt (line 2)) (6.5.0)
# Requirement already satisfied: sqlparse>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: docopt in /usr/local/lib/python3.9/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]->-r requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.9/dist-packages (from httplib2<0.22.0,>=0.8->apache-beam[gcp]->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]->-r requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]->-r requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib->gcsfs->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]->-r requirements.txt (line 2)) (1.58.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.9/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 3)) (6.0.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.9/dist-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]->-r requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs->-r requirements.txt (line 6)) (3.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 3)) (3.15.0)

# %% [markdown]
# ## Primer ejercicio
#
# Desarrollar un pipeline de preprocesamiento utilizando Apache Beam para generar datos de train, eval y test para los datos proporcionados anteriormente. Requisitos:
#
# - Proporcionar dos modos de ejecución: `train` y `test`
# - Soportar ejecuciones en local con `DirectRunner` y ejecuciones en Dataflow usando `DataFlowRunner`.

# %%
# %%writefile preprocess.py

"""A word-counting workflow."""

import argparse
import logging
import re
import os
import json
import random

import apache_beam as beam
from apache_beam.io import ReadFromText, WriteToText
from apache_beam.options.pipeline_options import PipelineOptions, SetupOptions, DirectOptions

import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

nltk.download("stopwords")

# Text preprocessing constants
STOP_WORDS = stopwords.words("english")
STEMMER = SnowballStemmer("english")
TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"


def extract_columns(element):
    element_json = json.loads(element)
    text = element_json["content"]
    sentiment = element_json["annotation"]["label"][0]
    return text, sentiment


def preprocess_columns_train(element):
    def process_sentiment(sentiment):
        sentiment = int(sentiment)
        return "TROLL" if sentiment == 1 else "NO_TROLL" if sentiment == 0 else "NEUTRAL"

    def process_text(text):
        text = re.sub(TEXT_CLEANING_RE, " ", str(text).lower()).strip()
        tokens = [token for token in text.split() if token not in STOP_WORDS]
        return " ".join(tokens)

    processed_text = process_text(element[0])
    processed_sentiment = process_sentiment(element[1])
    return f"{processed_text}, {processed_sentiment}"


def run(argv=None, save_main_session=True):
    parser = argparse.ArgumentParser()
    parser.add_argument("--work-dir", dest="work_dir", required=True, help="Working directory")
    parser.add_argument("--input", dest="input", required=True, help="Input dataset in work dir")
    parser.add_argument("--output", dest="output", required=True, help="Output path to store transformed data in work dir")
    parser.add_argument("--mode", dest="mode", required=True, choices=["train", "test"], help="Type of output to store transformed data")

    known_args, pipeline_args = parser.parse_known_args(argv)
    pipeline_options = PipelineOptions(pipeline_args)
    pipeline_options.view_as(SetupOptions).save_main_session = save_main_session
    pipeline_options.view_as(DirectOptions).direct_num_workers = 0

    with beam.Pipeline(options=pipeline_options) as p:
        raw_data = p | "ReadTwitterData" >> ReadFromText(known_args.input)

        if known_args.mode == "train":
            transformed_data = (
                raw_data
                | "ExtractColumns" >> beam.Map(extract_columns)
                | "Preprocess" >> beam.Map(preprocess_columns_train)
            )

            eval_percent = 20
            assert 0 < eval_percent < 100, "eval_percent must be in the range (0-100)"
            train_dataset, eval_dataset = (
                transformed_data
                | "Split dataset" >> beam.Partition(lambda elem, _: int(random.uniform(0, 100) < eval_percent), 2)
            )

            train_dataset | "TrainWriteToCSV" >> WriteToText(os.path.join(known_args.output, "train", "part"))
            eval_dataset | "EvalWriteToCSV" >> WriteToText(os.path.join(known_args.output, "eval", "part"))

        else:
            transformed_data = (
                raw_data
                | "ExtractColumns" >> beam.Map(extract_columns)
                | "Preprocess" >> beam.Map(lambda x: f'"{x[0]}"')
            )

            transformed_data | "TestWriteToCSV" >> WriteToText(
                os.path.join(known_args.output, "test", "part")
            )


if __name__ == "__main__":
    logging.getLogger().setLevel(logging.INFO)
    run()
# Out:
# Writing preprocess.py

# %% [markdown]
# Se proporciona un fichero `setup.py` necesario para ejecutar en DataFlow. Modificar la variable `REQUIRED_PACKAGES` con las dependencias que se hayan usado en el `requirements.txt`

# %%
# %%writefile setup.py

import setuptools

REQUIRED_PACKAGES = [
  "apache-beam[gcp]",
  "tensorflow",
  "gensim",
  "fsspec",
  "gcsfs",
  "numpy",
  "keras",
  "nltk"
]

setuptools.setup(
    name="twitchstreaming",
    version="0.0.1",
    install_requires=REQUIRED_PACKAGES,
    packages=setuptools.find_packages(),
    include_package_data=True,
    description="Troll detection",
)
# Out:
# Overwriting setup.py

# %% [markdown]
# ### Validación preprocess train en local
# Con el comando mostrado a continuación se valida la correcta generación de los datos de entrenamiento y validación en local.

# %%
WORK_DIR
# Out:
# '/content/batch'

# %%
! python3 preprocess.py \
  --work-dir $WORK_DIR \
  --runner DirectRunner \
  --input $WORK_DIR/data.json \
  --output $WORK_DIR/transformed_data \
  --mode train
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# WARNING:apache_beam.runners.portability.fn_api_runner.fn_runner:If direct_num_workers is not equal to 1, direct_running_mode should be `multi_processing` or `multi_threading` instead of `in_memory` in order for it to have the desired worker parallelism effect. direct_num_workers: 2 ; running_mode: in_memory
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function annotate_downstream_side_inputs at 0x7f594d2a18b0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function fix_side_input_pcoll_coders at 0x7f594d2a19d0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function pack_combiners at 0x7f594d2a1ee0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function lift_combiners at 0x7f594d2a1f70> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function expand_sdf at 0x7f594d2a2160> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function expand_gbk at 0x7f594d2a21f0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function sink_flattens at 0x7f594d2a2310> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function greedily_fuse at 0x7f594d2a23a0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function read_to_impulse at 0x7f594d2a2430> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function impulse_to_input at 0x7f594d2a24c0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function sort_stages at 0x7f594d2a2700> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function add_impulse_to_dangling_transforms at 0x7f594d2a2820> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function setup_timer_mapping at 0x7f594d2a2670> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function populate_data_channel_coders at 0x7f594d2a2790> ====================
# INFO:apache_beam.runners.worker.statecache:Creating state cache with size 104857600
# INFO:apache_beam.runners.portability.fn_api_runner.worker_handlers:Created Worker handler <apache_beam.runners.portability.fn_api_runner.worker_handlers.EmbeddedWorkerHandler object at 0x7f594d24a580> for environment ref_Environment_default_environment_1 (beam:env:embedded_python:v1, b'')
# INFO:apache_beam.runners.worker.statecache:Creating state cache with size 104857600
# INFO:apache_beam.runners.portability.fn_api_runner.worker_handlers:Created Worker handler <apache_beam.runners.portability.fn_api_runner.worker_handlers.EmbeddedWorkerHandler object at 0x7f594d24aee0> for environment ref_Environment_default_environment_1 (beam:env:embedded_python:v1, b'')
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:apache_beam.io.filebasedsink:Starting finalize_write threads with num_shards: 2 (skipped: 0), batches: 2, num_threads: 2
# INFO:apache_beam.io.filebasedsink:Renamed 2 shards in 0.00 seconds.
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:apache_beam.io.filebasedsink:Starting finalize_write threads with num_shards: 2 (skipped: 0), batches: 2, num_threads: 2
# INFO:apache_beam.io.filebasedsink:Renamed 2 shards in 0.00 seconds.

# %% [markdown]
# ### Validación preprocess test en local
#
# Con el comando mostrado a continuación se valida la correcta generación de los datos de test en local.

# %%
! python3 preprocess.py \
  --work-dir $WORK_DIR \
  --runner DirectRunner \
  --input $WORK_DIR/data.json \
  --output $WORK_DIR/transformed_data \
  --mode test
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# WARNING:apache_beam.runners.portability.fn_api_runner.fn_runner:If direct_num_workers is not equal to 1, direct_running_mode should be `multi_processing` or `multi_threading` instead of `in_memory` in order for it to have the desired worker parallelism effect. direct_num_workers: 2 ; running_mode: in_memory
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function annotate_downstream_side_inputs at 0x7f196cffd700> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function fix_side_input_pcoll_coders at 0x7f196cffd820> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function pack_combiners at 0x7f196cffdd30> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function lift_combiners at 0x7f196cffddc0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function expand_sdf at 0x7f196cffdf70> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function expand_gbk at 0x7f196cffe040> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function sink_flattens at 0x7f196cffe160> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function greedily_fuse at 0x7f196cffe1f0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function read_to_impulse at 0x7f196cffe280> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function impulse_to_input at 0x7f196cffe310> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function sort_stages at 0x7f196cffe550> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function add_impulse_to_dangling_transforms at 0x7f196cffe670> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function setup_timer_mapping at 0x7f196cffe4c0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function populate_data_channel_coders at 0x7f196cffe5e0> ====================
# INFO:apache_beam.runners.worker.statecache:Creating state cache with size 104857600
# INFO:apache_beam.runners.portability.fn_api_runner.worker_handlers:Created Worker handler <apache_beam.runners.portability.fn_api_runner.worker_handlers.EmbeddedWorkerHandler object at 0x7f196d1c3b20> for environment ref_Environment_default_environment_1 (beam:env:embedded_python:v1, b'')
# INFO:apache_beam.runners.worker.statecache:Creating state cache with size 104857600
# INFO:apache_beam.runners.portability.fn_api_runner.worker_handlers:Created Worker handler <apache_beam.runners.portability.fn_api_runner.worker_handlers.EmbeddedWorkerHandler object at 0x7f196cdffaf0> for environment ref_Environment_default_environment_1 (beam:env:embedded_python:v1, b'')
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:apache_beam.io.filebasedsink:Starting finalize_write threads with num_shards: 2 (skipped: 0), batches: 2, num_threads: 2
# INFO:apache_beam.io.filebasedsink:Renamed 2 shards in 0.00 seconds.

# %% [markdown]
# ## Segundo ejercicio
#
# Desarrollar una tarea de entrenamiento para los datos preprocesados. Requisitos:
#
# - Soportar ejecuciones en local usando el SDK de AI-Platform y ejecuciones en GCP con el mismo código.

# %% [markdown]
# Se crea el directorio donde trabajaremos:

# %%
# %mkdir /content/batch/trainer

# %%
# %%writefile trainer/__init__.py

version = "0.1.0"
# Out:
# Writing trainer/__init__.py

# %%
# %%writefile trainer/task.py

import os
import multiprocessing as mp
import logging
import tempfile
import pickle
import gensim
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Embedding, LSTM
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.preprocessing import LabelEncoder


W2V_SIZE = 300
W2V_WINDOW = 7
W2V_EPOCH = 5
W2V_MIN_COUNT = 10
SEQUENCE_LENGTH = 300
TROLL = "TROLL"
NO_TROLL = "NO_TROLL"
NEUTRAL = "NEUTRAL"
SENTIMENT_THRESHOLDS = (0.5, 0.6)
KERAS_MODEL = "model.h5"
WORD2VEC_MODEL = "model.w2v"
TOKENIZER_MODEL = "tokenizer.pkl"
ENCODER_MODEL = "encoder.pkl"


def generate_word2vec(train_df):
    documents = [_text.split() for _text in train_df.text.values]
    w2v_model = gensim.models.word2vec.Word2Vec(
        size=W2V_SIZE,
        window=W2V_WINDOW,
        min_count=W2V_MIN_COUNT,
        workers=mp.cpu_count(),
    )
    w2v_model.build_vocab(documents)

    words = w2v_model.wv.vocab.keys()
    vocab_size = len(words)
    logging.info(f"Vocabulario: {vocab_size}")
    w2v_model.train(documents, total_examples=len(documents), epochs=W2V_EPOCH)

    return w2v_model


def generate_tokenizer(train_df):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(train_df.text)
    vocab_size = len(tokenizer.word_index) + 1
    logging.info(f"Total palabras: {vocab_size}")
    return tokenizer, vocab_size


def generate_label_encoder(train_df):
    encoder = LabelEncoder()
    encoder.fit(train_df.sentiment.tolist())
    return encoder


def generate_embedding(word2vec_model, vocab_size, tokenizer):
    embedding_matrix = np.zeros((vocab_size, W2V_SIZE))
    for word, i in tokenizer.word_index.items():
        if word in word2vec_model.wv:
            embedding_matrix[i] = word2vec_model.wv[word]
    return Embedding(
        vocab_size,
        W2V_SIZE,
        weights=[embedding_matrix],
        input_length=SEQUENCE_LENGTH,
        trainable=False,
    )


def train_and_evaluate(work_dir, train_df, eval_df, batch_size=1024, epochs=8, steps=1000):
    model_dir = os.path.join(work_dir, "model")
    if tf.io.gfile.exists(model_dir):
        tf.io.gfile.rmtree(model_dir)
    tf.io.gfile.mkdir(model_dir)

    run_config = tf.estimator.RunConfig()
    run_config = run_config.replace(model_dir=model_dir)
    run_config = run_config.replace(save_summary_steps=10)

    logging.info("---- Generando modelo word2vec ----")
    word2vec_model = generate_word2vec(train_df)

    logging.info("---- Generando tokenizador ----")
    tokenizer, vocab_size = generate_tokenizer(train_df)

    logging.info("---- Datos de entrenamiento ----")
    x_train = pad_sequences(
        tokenizer.texts_to_sequences(train_df.text), maxlen=SEQUENCE_LENGTH
    )
    logging.info("---- Datos de evaluacion ----")
    x_eval = pad_sequences(
        tokenizer.texts_to_sequences(eval_df.text), maxlen=SEQUENCE_LENGTH
    )

    logging.info("---- Generando encoder ----")
    label_encoder = generate_label_encoder(train_df)

    logging.info("---- Encoder de entrenamiento ----")
    y_train = label_encoder.transform(train_df.sentiment.tolist())
    logging.info("---- Encoder de evaluacion ----")
    y_eval = label_encoder.transform(eval_df.sentiment.tolist())

    y_train = y_train.reshape(-1, 1)
    y_eval = y_eval.reshape(-1, 1)

    logging.info("---- Generando la embedding layer ----")
    embedding_layer = generate_embedding(word2vec_model, vocab_size, tokenizer)

    logging.info("---- modelo ----")
    model = Sequential()
    model.add(embedding_layer)
    model.add(Dropout(0.5))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation="sigmoid"))

    model.summary()

    logging.info("---- Función de pérdida ----")
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

    logging.info("---- Funciones para detener ----")
    callbacks = [
        ReduceLROnPlateau(monitor="val_loss", patience=5, cooldown=0),
        EarlyStopping(monitor="val_accuracy", min_delta=1e-4, patience=5),
    ]

    logging.info("---- Entrenando ----")
    model.fit(
        x_train,
        y_train,
        batch_size=batch_size,
        steps_per_epoch=steps,
        epochs=epochs,
        validation_split=0.1,
        verbose=1,
        callbacks=callbacks,
    )

    logging.info("---- Evaluando ----")
    score = model.evaluate(x_eval, y_eval, batch_size=batch_size)
    logging.info(f"ACCURACY: {score[1]}")
    logging.info(f"LOSS: {score[0]}")

    logging.info("---- Guardando modelos ----")
    pickle.dump(
        tokenizer,
        tf.io.gfile.GFile(os.path.join(model_dir, TOKENIZER_MODEL), mode="wb"),
        protocol=0,
    )
    with tempfile.NamedTemporaryFile(suffix=".h5") as local_file:
        with tf.io.gfile.GFile(
            os.path.join(model_dir, KERAS_MODEL), mode="wb"
        ) as gcs_file:
            model.save(local_file.name)
            gcs_file.write(local_file.read())

def main(work_dir, batch_size=1024, epochs=8, steps=1000):
    logging.getLogger().setLevel(logging.INFO)

    train_data_files = tf.io.gfile.glob(
        os.path.join(work_dir, "transformed_data/train/part-*")
    )
    eval_data_files = tf.io.gfile.glob(
        os.path.join(work_dir, "transformed_data/eval/part-*")
    )

    train_df = pd.concat(
        [
            pd.read_csv(
                f,
                names=["text", "sentiment"],
                dtype={"text": "string", "sentiment": "string"},
            )
            for f in train_data_files
        ]
    ).dropna()

    eval_df = pd.concat(
        [
            pd.read_csv(
                f,
                names=["text", "sentiment"],
                dtype={"text": "string", "sentiment": "string"},
            )
            for f in eval_data_files
        ]
       ).dropna()

    train_and_evaluate(
        work_dir,
        train_df=train_df,
        eval_df=eval_df,
        batch_size=batch_size,
        epochs=epochs,
        steps=steps,
    )


if __name__ == "__main__":
    import argparse

    parser = argparse.ArgumentParser(
        formatter_class=argparse.ArgumentDefaultsHelpFormatter
    )

    parser.add_argument(
        "--work-dir",
        required=True,
        help="Directory for staging and working files. "
        "This can be a Google Cloud Storage path.",
    )

    parser.add_argument(
        "--batch-size",
        type=int,
        default=1024,
        help="Batch size for training and evaluation.",
    )

    parser.add_argument(
        "--epochs", type=int, default=8, help="Number of epochs to train the model",
    )

    parser.add_argument(
        "--steps",
        type=int,
        default=1000,
        help="Number of steps per epoch to train the model",
    )

    args = parser.parse_args()

    main(
        work_dir=args.work_dir,
        batch_size=args.batch_size,
        epochs=args.epochs,
        steps=args.steps,
    )
# Out:
# Overwriting trainer/task.py

# %% [markdown]
# ### Validación Train en local
#
# Con el comando mostrado a continuación se valida el correcto entrenamiento del modelo usando los datos preprocesados del apartado anterior.

# %%
# Explicitly tell `gcloud ai-platform local train` to use Python 3 
! gcloud config set ml_engine/local_python $(which python3)

# This is similar to `python -m trainer.task --job-dir local-training-output`
# but it better replicates the AI Platform environment, especially for
# distributed training (not applicable here).
! gcloud ai-platform local train \
  --package-path trainer \
  --module-name trainer.task \
  -- \
  --work-dir $WORK_DIR \
  --epochs 1
# Out:
# Updated property [ml_engine/local_python].
# 2023-03-19 21:08:08.648423: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-19 21:08:09.475167: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-19 21:08:09.475285: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-19 21:08:09.475304: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# INFO:tensorflow:TF_CONFIG environment variable: {'job': {'job_name': 'trainer.task', 'args': ['--work-dir', '/content/batch', '--epochs', '1']}, 'task': {}, 'cluster': {}, 'environment': 'cloud'}
# INFO:root:---- Generando modelo word2vec ----
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 68120 words, keeping 11579 word types
# INFO:gensim.models.word2vec:collected 14669 word types from a corpus of 113439 raw words and 15802 sentences
# INFO:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:gensim.models.word2vec:effective_min_count=10 retains 1590 unique words (10% of original 14669, drops 13079)
# INFO:gensim.models.word2vec:effective_min_count=10 leaves 84020 word corpus (74% of original 113439, drops 29419)
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 14669 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 57 most-common words
# INFO:gensim.models.word2vec:downsampling leaves estimated 69929 word corpus (83.2% of prior 84020)
# INFO:gensim.models.base_any2vec:estimated required memory for 1590 words and 300 dimensions: 4611000 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:root:Vocabulario: 1590
# INFO:gensim.models.base_any2vec:training model with 2 workers on 1590 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 1 : training on 113439 raw words (69777 effective words) took 0.1s, 527852 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 2 : training on 113439 raw words (69810 effective words) took 0.1s, 540541 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 3 : training on 113439 raw words (70032 effective words) took 0.1s, 560160 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 4 : training on 113439 raw words (70009 effective words) took 0.1s, 481603 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 5 : training on 113439 raw words (69933 effective words) took 0.1s, 560732 effective words/s
# INFO:gensim.models.base_any2vec:training on a 567195 raw words (349561 effective words) took 0.7s, 510533 effective words/s
# INFO:root:---- Generando tokenizador ----
# INFO:root:Total palabras: 14670
# INFO:root:---- Datos de entrenamiento ----
# INFO:root:---- Datos de evaluacion ----
# INFO:root:---- Generando encoder ----
# INFO:root:---- Encoder de entrenamiento ----
# INFO:root:---- Encoder de evaluacion ----
# INFO:root:---- Generando la embedding layer ----
# INFO:root:---- modelo ----
# 2023-03-19 21:08:13.389291: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 300)          4401000
#
#  dropout (Dropout)           (None, 300, 300)          0
#
#  lstm (LSTM)                 (None, 100)               160400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 4,561,501
# Trainable params: 160,501
# Non-trainable params: 4,401,000
# _________________________________________________________________
# INFO:root:---- Función de pérdida ----
# INFO:root:---- Funciones para detener ----
# INFO:root:---- Entrenando ----
#   14/1000 [..............................] - ETA: 20:40 - loss: 0.6886 - accuracy: 0.5668WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1000 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1000 batches). You may need to use the repeat() function when building your dataset.
# 1000/1000 [==============================] - 23s 18ms/step - loss: 0.6886 - accuracy: 0.5668 - val_loss: 0.7064 - val_accuracy: 0.4605 - lr: 0.0010
# INFO:root:---- Evaluando ----
# 4/4 [==============================] - 0s 96ms/step - loss: 0.6803 - accuracy: 0.5855
# INFO:root:ACCURACY: 0.5854973196983337
# INFO:root:LOSS: 0.6802952885627747
# INFO:root:---- Guardando modelos ----

# %% [markdown]
# ## Tercer ejercicio
#
# Desarrollar un pipeline de inferencia utilizando Apache Beam para generar predicciones usando los modelos generados en el apartado anterior así como los datos de test generados en el primer ejercicio.

# %%
# %%writefile predict.py

from __future__ import absolute_import, print_function

import argparse
import json
import os
import sys
import tempfile
import time

import apache_beam as beam
import pickle
import tensorflow as tf
from apache_beam.coders.coders import Coder
from apache_beam.io import ReadFromText, WriteToText
from apache_beam.options.pipeline_options import (
    DirectOptions,
    GoogleCloudOptions,
    PipelineOptions,
    SetupOptions,
)
from tensorflow.keras.preprocessing.sequence import pad_sequences

SEQUENCE_LENGTH = 300

TROLL = "TROLL"
NO_TROLL = "NO_TROLL"
NEUTRAL = "NEUTRAL"
SENTIMENT_THRESHOLDS = (0.5, 0.6)

KERAS_MODEL = "model.h5"
TOKENIZER_MODEL = "tokenizer.pkl"


class CustomCoder(Coder):
    def __init__(self, encoding: str):
        self.enconding = encoding

    def encode(self, value):
        return value.encode(self.enconding)

    def decode(self, value):
        return value.decode(self.enconding)

    def is_deterministic(self):
        return True


class Predict(beam.DoFn):
    def __init__(self, model_dir):
        self.model_dir = model_dir
        self.model = None
        self.tokenizer = None

    def setup(self):
        keras_model_path = os.path.join(self.model_dir, KERAS_MODEL)
        tokenizer_path = os.path.join(self.model_dir, TOKENIZER_MODEL)

        with tempfile.NamedTemporaryFile(suffix=".h5") as local_file:
            with tf.io.gfile.GFile(keras_model_path, mode="rb") as gcs_file:
                local_file.write(gcs_file.read())
                self.model = tf.keras.models.load_model(local_file.name)

        self.tokenizer = pickle.load(tf.io.gfile.GFile(tokenizer_path, mode="rb"))

    def decode_sentiment(self, score, include_neutral=True):
        if include_neutral:
            label = NEUTRAL
            if score <= SENTIMENT_THRESHOLDS[0]:
                label = NO_TROLL
            elif score >= SENTIMENT_THRESHOLDS[1]:
                label = TROLL
            return label
        else:
            return NO_TROLL if score < 0.5 else TROLL

    def process(self, element):
        start_at = time.time()
        x_test = pad_sequences(
            self.tokenizer.texts_to_sequences([element]), maxlen=SEQUENCE_LENGTH
        )
        score = self.model.predict([x_test])[0]
        label = self.decode_sentiment(score)

        yield {
            "text": element,
            "label": label,
            "score": float(score),
            "elapsed_time": time.time() - start_at,
        }


def run(model_dir, source, sink, beam_options=None):
    with beam.Pipeline(options=beam_options) as p:
        _ = (
            p
            | "Read data" >> source
            | "Predict" >> beam.ParDo(Predict(model_dir))
            | "Format as JSON" >> beam.Map(json.dumps)
            | "Write predictions" >> sink
        )


def main():
    parser = argparse.ArgumentParser(
        formatter_class=argparse.ArgumentDefaultsHelpFormatter
    )

    parser.add_argument("--work-dir", dest="work_dir", required=True)
    parser.add_argument("--model-dir", dest="model_dir", required=True)

    verbs = parser.add_subparsers(dest="verb")
    batch_verb = verbs.add_parser("batch", help="Batch prediction")
    batch_verb.add_argument("--inputs-dir", dest="inputs_dir", required=True)
    batch_verb.add_argument("--outputs-dir", dest="outputs_dir", required=True)

    args, pipeline_args = parser.parse_known_args()
    beam_options = PipelineOptions(pipeline_args)
    beam_options.view_as(SetupOptions).save_main_session = True
    beam_options.view_as(DirectOptions).direct_num_workers = 0

    project = beam_options.view_as(GoogleCloudOptions).project

    if args.verb == "batch":
        results_prefix = os.path.join(args.outputs_dir, "part")

        source = ReadFromText(args.inputs_dir, coder=CustomCoder("latin-1"))
        sink = WriteToText(results_prefix)

    else:
        parser.print_usage()
        sys.exit(1)

    run(args.model_dir, source, sink, beam_options)


if __name__ == "__main__":
    main()
# Out:
# Overwriting predict.py

# %% [markdown]
# Generamos un timestamp para la ejecución de las predicciones

# %%
from datetime import datetime

# current date and time
TIMESTAMP = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

# %% [markdown]
# ### Validación Predict en local
#
# Con el comando mostrado a continuación se valida la correcta inferencia usando los modelos anteriores y los datos de test generados anteriormente.

# %%
! python3 predict.py \
  --work-dir $WORK_DIR \
  --model-dir $WORK_DIR/model \
  batch \
  --inputs-dir $WORK_DIR/transformed_data/test/part* \
  --outputs-dir $WORK_DIR/predictions/$TIMESTAMP
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 121ms/step
# ...
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step

# %% [markdown]
# ## Extra. Comprobaciones en la nube
#
# En esta última parte se validará el funcionamiento del código en un proyecto de GCP sobre DataFlow y AI Platform

# %% [markdown]
# Establecemos el bucket y region de GCP sobre el que trabajaremos:

# %%
GCP_WORK_DIR = 'gs://' + BUCKET_NAME + '/final'
GCP_REGION = REGION

# %%
GCP_WORK_DIR
# Out:
# 'gs://produccionkc/final'

# %%
GCP_REGION
# Out:
# 'europe-west1'

# %% [markdown]
# ### Validación preprocess train en Dataflow
#
# Con el comando mostrado a continuación se valida la correcta generación de los datos de entrenamiento y validación en GCP con el servicio DataFlow.

# %%
! python3 preprocess.py \
  --project $PROJECT_ID \
  --region $GCP_REGION \
  --runner DataflowRunner \
  --temp_location $GCP_WORK_DIR/beam-temp \
  --setup_file ./setup.py \
  --work-dir $GCP_WORK_DIR \
  --input $GCP_WORK_DIR/data.json \
  --output $GCP_WORK_DIR/transformed_data \
  --mode train
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# INFO:apache_beam.internal.gcp.auth:Setting socket default timeout to 60 seconds.
# INFO:apache_beam.internal.gcp.auth:socket default timeout is 60.0 seconds.
# WARNING:google.auth._default:No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable
# INFO:apache_beam.runners.portability.stager:Executing command: ['/usr/bin/python3', 'setup.py', 'sdist', '--dist-dir', '/tmp/tmp94nyjqo4']
# warning: sdist: standard file not found: should have one of README, README.rst, README.txt, README.md
#
# warning: check: missing required meta-data: url
#
# warning: check: missing meta-data: either (author and author_email) or (maintainer and maintainer_email) should be supplied
#
# INFO:apache_beam.runners.portability.stager:Downloading source distribution of the SDK from PyPi
# INFO:apache_beam.runners.portability.stager:Executing command: ['/usr/bin/python3', '-m', 'pip', 'download', '--dest', '/tmp/tmp94nyjqo4', 'apache-beam==2.46.0', '--no-deps', '--no-binary', ':all:']
# INFO:apache_beam.runners.portability.stager:Staging SDK sources from PyPI: dataflow_python_sdk.tar
# INFO:apache_beam.runners.portability.stager:Downloading binary distribution of the SDK from PyPi
# INFO:apache_beam.runners.portability.stager:Executing command: ['/usr/bin/python3', '-m', 'pip', 'download', '--dest', '/tmp/tmp94nyjqo4', 'apache-beam==2.46.0', '--no-deps', '--only-binary', ':all:', '--python-version', '39', '--implementation', 'cp', '--abi', 'cp39', '--platform', 'manylinux2014_x86_64']
# INFO:apache_beam.runners.portability.stager:Staging binary distribution of the SDK from PyPI: apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Using provided Python SDK container image: gcr.io/cloud-dataflow/v1beta3/python39:2.46.0
# INFO:root:Python SDK container image set to "gcr.io/cloud-dataflow/v1beta3/python39:2.46.0" for Docker environment
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function pack_combiners at 0x7fe94c923430> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function sort_stages at 0x7fe94c923c10> ====================
# INFO:apache_beam.runners.dataflow.internal.apiclient:Defaulting to the temp_location as staging_location: gs://produccionkc/final/beam-temp
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/pickled_main_session...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/pickled_main_session in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/dataflow_python_sdk.tar...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/dataflow_python_sdk.tar in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/workflow.tar.gz...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/workflow.tar.gz in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl in 1 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/pipeline.pb...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221128-629680-w4ppqu0p.1679263888.629940/pipeline.pb in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Create job: <Job
#  clientRequestId: '20230319221128630661-7100'
#  createTime: '2023-03-19T22:11:31.866209Z'
#  currentStateTime: '1970-01-01T00:00:00Z'
#  id: '2023-03-19_15_11_31-11637244565532394311'
#  location: 'europe-west1'
#  name: 'beamapp-root-0319221128-629680-w4ppqu0p'
#  projectId: 'serious-studio-380614'
#  stageStates: []
#  startTime: '2023-03-19T22:11:31.866209Z'
#  steps: []
#  tempFiles: []
#  type: TypeValueValuesEnum(JOB_TYPE_BATCH, 1)>
# INFO:apache_beam.runners.dataflow.internal.apiclient:Created job with id: [2023-03-19_15_11_31-11637244565532394311]
# INFO:apache_beam.runners.dataflow.internal.apiclient:Submitted job: 2023-03-19_15_11_31-11637244565532394311
# INFO:apache_beam.runners.dataflow.internal.apiclient:To access the Dataflow monitoring console, please navigate to https://console.cloud.google.com/dataflow/jobs/europe-west1/2023-03-19_15_11_31-11637244565532394311?project=serious-studio-380614
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2023-03-19_15_11_31-11637244565532394311 is in state JOB_STATE_PENDING
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:31.340Z: JOB_MESSAGE_BASIC: Dataflow Runner V2 auto-enabled. Use --experiments=disable_runner_v2 to opt out.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:33.524Z: JOB_MESSAGE_DETAILED: Autoscaling is enabled for job 2023-03-19_15_11_31-11637244565532394311. The number of workers will be between 1 and 1000.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:33.645Z: JOB_MESSAGE_DETAILED: Autoscaling was automatically enabled for job 2023-03-19_15_11_31-11637244565532394311.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:35.857Z: JOB_MESSAGE_BASIC: Worker configuration: n1-standard-1 in europe-west1-b.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.667Z: JOB_MESSAGE_DETAILED: Expanding SplittableParDo operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.689Z: JOB_MESSAGE_DETAILED: Expanding CollectionToSingleton operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.745Z: JOB_MESSAGE_DETAILED: Expanding CoGroupByKey operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.768Z: JOB_MESSAGE_DEBUG: Combiner lifting skipped for step TrainWriteToCSV/Write/WriteImpl/GroupByKey: GroupByKey not followed by a combiner.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.797Z: JOB_MESSAGE_DEBUG: Combiner lifting skipped for step EvalWriteToCSV/Write/WriteImpl/GroupByKey: GroupByKey not followed by a combiner.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.829Z: JOB_MESSAGE_DETAILED: Expanding GroupByKey operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.854Z: JOB_MESSAGE_DEBUG: Annotating graph with Autotuner information.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.893Z: JOB_MESSAGE_DETAILED: Fusing adjacent ParDo, Read, Write, and Flatten operations
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.928Z: JOB_MESSAGE_DETAILED: Fusing consumer EvalWriteToCSV/Write/WriteImpl/InitializeWrite into EvalWriteToCSV/Write/WriteImpl/DoOnce/Map(decode)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.962Z: JOB_MESSAGE_DETAILED: Fusing consumer TrainWriteToCSV/Write/WriteImpl/InitializeWrite into TrainWriteToCSV/Write/WriteImpl/DoOnce/Map(decode)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:36.999Z: JOB_MESSAGE_DETAILED: Fusing consumer EvalWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>) into EvalWriteToCSV/Write/WriteImpl/DoOnce/Impulse
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.030Z: JOB_MESSAGE_DETAILED: Fusing consumer EvalWriteToCSV/Write/WriteImpl/DoOnce/Map(decode) into EvalWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.063Z: JOB_MESSAGE_DETAILED: Fusing consumer ReadTwitterData/Read/Map(<lambda at iobase.py:908>) into ReadTwitterData/Read/Impulse
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.092Z: JOB_MESSAGE_DETAILED: Fusing consumer ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/PairWithRestriction into ReadTwitterData/Read/Map(<lambda at iobase.py:908>)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.119Z: JOB_MESSAGE_DETAILED: Fusing consumer ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/SplitWithSizing into ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/PairWithRestriction
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.153Z: JOB_MESSAGE_DETAILED: Fusing consumer ExtractColumns into ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/ProcessElementAndRestrictionWithSizing
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.184Z: JOB_MESSAGE_DETAILED: Fusing consumer Preprocess into ExtractColumns
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.209Z: JOB_MESSAGE_DETAILED: Fusing consumer Split dataset/ParDo(ApplyPartitionFnFn)/ParDo(ApplyPartitionFnFn) into Preprocess
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.240Z: JOB_MESSAGE_DETAILED: Fusing consumer EvalWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn) into Split dataset/ParDo(ApplyPartitionFnFn)/ParDo(ApplyPartitionFnFn)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.264Z: JOB_MESSAGE_DETAILED: Fusing consumer EvalWriteToCSV/Write/WriteImpl/WriteBundles into EvalWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.295Z: JOB_MESSAGE_DETAILED: Fusing consumer EvalWriteToCSV/Write/WriteImpl/Pair into EvalWriteToCSV/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.328Z: JOB_MESSAGE_DETAILED: Fusing consumer EvalWriteToCSV/Write/WriteImpl/GroupByKey/Write into EvalWriteToCSV/Write/WriteImpl/Pair
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.361Z: JOB_MESSAGE_DETAILED: Fusing consumer EvalWriteToCSV/Write/WriteImpl/Extract into EvalWriteToCSV/Write/WriteImpl/GroupByKey/Read
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.383Z: JOB_MESSAGE_DETAILED: Fusing consumer TrainWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>) into TrainWriteToCSV/Write/WriteImpl/DoOnce/Impulse
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.438Z: JOB_MESSAGE_DETAILED: Fusing consumer TrainWriteToCSV/Write/WriteImpl/DoOnce/Map(decode) into TrainWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.471Z: JOB_MESSAGE_DETAILED: Fusing consumer TrainWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn) into Split dataset/ParDo(ApplyPartitionFnFn)/ParDo(ApplyPartitionFnFn)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.502Z: JOB_MESSAGE_DETAILED: Fusing consumer TrainWriteToCSV/Write/WriteImpl/WriteBundles into TrainWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.536Z: JOB_MESSAGE_DETAILED: Fusing consumer TrainWriteToCSV/Write/WriteImpl/Pair into TrainWriteToCSV/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.565Z: JOB_MESSAGE_DETAILED: Fusing consumer TrainWriteToCSV/Write/WriteImpl/GroupByKey/Write into TrainWriteToCSV/Write/WriteImpl/Pair
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.594Z: JOB_MESSAGE_DETAILED: Fusing consumer TrainWriteToCSV/Write/WriteImpl/Extract into TrainWriteToCSV/Write/WriteImpl/GroupByKey/Read
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.647Z: JOB_MESSAGE_DEBUG: Workflow config is missing a default resource spec.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.679Z: JOB_MESSAGE_DEBUG: Adding StepResource setup and teardown to workflow graph.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.710Z: JOB_MESSAGE_DEBUG: Adding workflow start and stop steps.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:37.742Z: JOB_MESSAGE_DEBUG: Assigning stage ids.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:38.029Z: JOB_MESSAGE_DEBUG: Executing wait step start28
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:38.086Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/DoOnce/Impulse+TrainWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)+TrainWriteToCSV/Write/WriteImpl/DoOnce/Map(decode)+TrainWriteToCSV/Write/WriteImpl/InitializeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:38.117Z: JOB_MESSAGE_BASIC: Executing operation ReadTwitterData/Read/Impulse+ReadTwitterData/Read/Map(<lambda at iobase.py:908>)+ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/PairWithRestriction+ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/SplitWithSizing
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:38.131Z: JOB_MESSAGE_DEBUG: Starting worker pool setup.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:38.145Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/DoOnce/Impulse+EvalWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)+EvalWriteToCSV/Write/WriteImpl/DoOnce/Map(decode)+EvalWriteToCSV/Write/WriteImpl/InitializeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:11:38.155Z: JOB_MESSAGE_BASIC: Starting 1 workers in europe-west1-b...
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2023-03-19_15_11_31-11637244565532394311 is in state JOB_STATE_RUNNING
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:12:11.944Z: JOB_MESSAGE_DETAILED: Autoscaling: Raised the number of workers to 1 based on the rate of progress in the currently running stage(s).
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:12:54.688Z: JOB_MESSAGE_DETAILED: Workers have started successfully.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:11.353Z: JOB_MESSAGE_DETAILED: All workers have finished the startup processes and began to receive work requests.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.504Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/DoOnce/Impulse+TrainWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)+TrainWriteToCSV/Write/WriteImpl/DoOnce/Map(decode)+TrainWriteToCSV/Write/WriteImpl/InitializeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.567Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/DoOnce/Map(decode).None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.590Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/InitializeWrite.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.652Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/WriteBundles/View-python_side_input0-TrainWriteToCSV/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.684Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input0-TrainWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.714Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/WriteBundles/View-python_side_input0-TrainWriteToCSV/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.718Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input0-TrainWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.742Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input0-TrainWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.778Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/WriteBundles/View-python_side_input0-TrainWriteToCSV/Write/WriteImpl/WriteBundles.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.791Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input0-TrainWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.823Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input0-TrainWriteToCSV/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:13.856Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input0-TrainWriteToCSV/Write/WriteImpl/PreFinalize.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:16.867Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/DoOnce/Impulse+EvalWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)+EvalWriteToCSV/Write/WriteImpl/DoOnce/Map(decode)+EvalWriteToCSV/Write/WriteImpl/InitializeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:16.950Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/DoOnce/Map(decode).None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:16.983Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/InitializeWrite.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:17.050Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/WriteBundles/View-python_side_input0-EvalWriteToCSV/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:17.082Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input0-EvalWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:17.102Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/WriteBundles/View-python_side_input0-EvalWriteToCSV/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:17.113Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input0-EvalWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:17.143Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input0-EvalWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:17.170Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/WriteBundles/View-python_side_input0-EvalWriteToCSV/Write/WriteImpl/WriteBundles.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:17.174Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input0-EvalWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:17.212Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input0-EvalWriteToCSV/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:17.248Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input0-EvalWriteToCSV/Write/WriteImpl/PreFinalize.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:20.643Z: JOB_MESSAGE_BASIC: Finished operation ReadTwitterData/Read/Impulse+ReadTwitterData/Read/Map(<lambda at iobase.py:908>)+ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/PairWithRestriction+ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/SplitWithSizing
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:20.708Z: JOB_MESSAGE_DEBUG: Value "ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7-split-with-sizing-out3" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:20.787Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:20.818Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:23.752Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:23.830Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/GroupByKey/Session" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:26.888Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:26.956Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/GroupByKey/Session" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:27.009Z: JOB_MESSAGE_BASIC: Executing operation ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/ProcessElementAndRestrictionWithSizing+ExtractColumns+Preprocess+Split dataset/ParDo(ApplyPartitionFnFn)/ParDo(ApplyPartitionFnFn)+EvalWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn)+EvalWriteToCSV/Write/WriteImpl/WriteBundles+EvalWriteToCSV/Write/WriteImpl/Pair+EvalWriteToCSV/Write/WriteImpl/GroupByKey/Write+TrainWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn)+TrainWriteToCSV/Write/WriteImpl/WriteBundles+TrainWriteToCSV/Write/WriteImpl/Pair+TrainWriteToCSV/Write/WriteImpl/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:42.452Z: JOB_MESSAGE_BASIC: Finished operation ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/ProcessElementAndRestrictionWithSizing+ExtractColumns+Preprocess+Split dataset/ParDo(ApplyPartitionFnFn)/ParDo(ApplyPartitionFnFn)+EvalWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn)+EvalWriteToCSV/Write/WriteImpl/WriteBundles+EvalWriteToCSV/Write/WriteImpl/Pair+EvalWriteToCSV/Write/WriteImpl/GroupByKey/Write+TrainWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn)+TrainWriteToCSV/Write/WriteImpl/WriteBundles+TrainWriteToCSV/Write/WriteImpl/Pair+TrainWriteToCSV/Write/WriteImpl/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:42.523Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:42.558Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:42.605Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:42.670Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/GroupByKey/Read+EvalWriteToCSV/Write/WriteImpl/Extract
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:43.245Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:43.310Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/GroupByKey/Read+TrainWriteToCSV/Write/WriteImpl/Extract
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:46.176Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/GroupByKey/Read+EvalWriteToCSV/Write/WriteImpl/Extract
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:46.245Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/Extract.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:46.310Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input1-EvalWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:46.344Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input1-EvalWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:46.356Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input1-EvalWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:46.411Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input1-EvalWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:46.415Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input1-EvalWriteToCSV/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:46.483Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input1-EvalWriteToCSV/Write/WriteImpl/PreFinalize.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:46.543Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:49.504Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/GroupByKey/Read+TrainWriteToCSV/Write/WriteImpl/Extract
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:49.581Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/Extract.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:49.639Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input1-TrainWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:49.672Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input1-TrainWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:49.691Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input1-TrainWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:49.741Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input1-TrainWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:49.782Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input1-TrainWriteToCSV/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:49.816Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input1-TrainWriteToCSV/Write/WriteImpl/PreFinalize.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:49.872Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:53.069Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:53.134Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/PreFinalize.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:53.205Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input2-TrainWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:53.259Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input2-TrainWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:53.326Z: JOB_MESSAGE_DEBUG: Value "TrainWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input2-TrainWriteToCSV/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:53.392Z: JOB_MESSAGE_BASIC: Executing operation TrainWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:17:56.622Z: JOB_MESSAGE_BASIC: Finished operation TrainWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:00.665Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:00.722Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/PreFinalize.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:00.788Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input2-EvalWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:00.842Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input2-EvalWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:00.897Z: JOB_MESSAGE_DEBUG: Value "EvalWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input2-EvalWriteToCSV/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:00.968Z: JOB_MESSAGE_BASIC: Executing operation EvalWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:04.008Z: JOB_MESSAGE_BASIC: Finished operation EvalWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:04.076Z: JOB_MESSAGE_DEBUG: Executing success step success26
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:04.158Z: JOB_MESSAGE_DETAILED: Cleaning up.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:04.214Z: JOB_MESSAGE_DEBUG: Starting worker pool teardown.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:18:04.240Z: JOB_MESSAGE_BASIC: Stopping worker pool...
#
# ^C

# %% [markdown]
# ### Validación preprocess test en Dataflow
#
# Con el comando mostrado a continuación se valida la correcta generación de los datos de test en GCP con el servicio DataFlow.

# %%
! python3 preprocess.py \
  --project $PROJECT_ID \
  --region $GCP_REGION \
  --runner DataflowRunner \
  --temp_location $GCP_WORK_DIR/beam-temp \
  --setup_file ./setup.py \
  --work-dir $GCP_WORK_DIR \
  --input $GCP_WORK_DIR/data.json \
  --output $GCP_WORK_DIR/transformed_data \
  --mode test
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# INFO:apache_beam.internal.gcp.auth:Setting socket default timeout to 60 seconds.
# INFO:apache_beam.internal.gcp.auth:socket default timeout is 60.0 seconds.
# WARNING:google.auth._default:No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable
# INFO:apache_beam.runners.portability.stager:Executing command: ['/usr/bin/python3', 'setup.py', 'sdist', '--dist-dir', '/tmp/tmp_1hkchlg']
# warning: sdist: standard file not found: should have one of README, README.rst, README.txt, README.md
#
# warning: check: missing required meta-data: url
#
# warning: check: missing meta-data: either (author and author_email) or (maintainer and maintainer_email) should be supplied
#
# INFO:apache_beam.runners.portability.stager:Downloading source distribution of the SDK from PyPi
# INFO:apache_beam.runners.portability.stager:Executing command: ['/usr/bin/python3', '-m', 'pip', 'download', '--dest', '/tmp/tmp_1hkchlg', 'apache-beam==2.46.0', '--no-deps', '--no-binary', ':all:']
# INFO:apache_beam.runners.portability.stager:Staging SDK sources from PyPI: dataflow_python_sdk.tar
# INFO:apache_beam.runners.portability.stager:Downloading binary distribution of the SDK from PyPi
# INFO:apache_beam.runners.portability.stager:Executing command: ['/usr/bin/python3', '-m', 'pip', 'download', '--dest', '/tmp/tmp_1hkchlg', 'apache-beam==2.46.0', '--no-deps', '--only-binary', ':all:', '--python-version', '39', '--implementation', 'cp', '--abi', 'cp39', '--platform', 'manylinux2014_x86_64']
# INFO:apache_beam.runners.portability.stager:Staging binary distribution of the SDK from PyPI: apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Using provided Python SDK container image: gcr.io/cloud-dataflow/v1beta3/python39:2.46.0
# INFO:root:Python SDK container image set to "gcr.io/cloud-dataflow/v1beta3/python39:2.46.0" for Docker environment
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function pack_combiners at 0x7f94db7ce9d0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function sort_stages at 0x7f94db7cf1f0> ====================
# INFO:apache_beam.runners.dataflow.internal.apiclient:Defaulting to the temp_location as staging_location: gs://produccionkc/final/beam-temp
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/pickled_main_session...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/pickled_main_session in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/dataflow_python_sdk.tar...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/dataflow_python_sdk.tar in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/workflow.tar.gz...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/workflow.tar.gz in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl in 1 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/pipeline.pb...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://produccionkc/final/beam-temp/beamapp-root-0319221925-776833-6uzjjcoz.1679264365.777213/pipeline.pb in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Create job: <Job
#  clientRequestId: '20230319221925778487-4081'
#  createTime: '2023-03-19T22:19:29.088430Z'
#  currentStateTime: '1970-01-01T00:00:00Z'
#  id: '2023-03-19_15_19_28-12573703514186177624'
#  location: 'europe-west1'
#  name: 'beamapp-root-0319221925-776833-6uzjjcoz'
#  projectId: 'serious-studio-380614'
#  stageStates: []
#  startTime: '2023-03-19T22:19:29.088430Z'
#  steps: []
#  tempFiles: []
#  type: TypeValueValuesEnum(JOB_TYPE_BATCH, 1)>
# INFO:apache_beam.runners.dataflow.internal.apiclient:Created job with id: [2023-03-19_15_19_28-12573703514186177624]
# INFO:apache_beam.runners.dataflow.internal.apiclient:Submitted job: 2023-03-19_15_19_28-12573703514186177624
# INFO:apache_beam.runners.dataflow.internal.apiclient:To access the Dataflow monitoring console, please navigate to https://console.cloud.google.com/dataflow/jobs/europe-west1/2023-03-19_15_19_28-12573703514186177624?project=serious-studio-380614
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2023-03-19_15_19_28-12573703514186177624 is in state JOB_STATE_PENDING
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:28.582Z: JOB_MESSAGE_BASIC: Dataflow Runner V2 auto-enabled. Use --experiments=disable_runner_v2 to opt out.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:30.444Z: JOB_MESSAGE_DETAILED: Autoscaling is enabled for job 2023-03-19_15_19_28-12573703514186177624. The number of workers will be between 1 and 1000.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:30.581Z: JOB_MESSAGE_DETAILED: Autoscaling was automatically enabled for job 2023-03-19_15_19_28-12573703514186177624.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:32.481Z: JOB_MESSAGE_BASIC: Worker configuration: n1-standard-1 in europe-west1-b.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.303Z: JOB_MESSAGE_DETAILED: Expanding SplittableParDo operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.360Z: JOB_MESSAGE_DETAILED: Expanding CollectionToSingleton operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.414Z: JOB_MESSAGE_DETAILED: Expanding CoGroupByKey operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.450Z: JOB_MESSAGE_DEBUG: Combiner lifting skipped for step TestWriteToCSV/Write/WriteImpl/GroupByKey: GroupByKey not followed by a combiner.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.489Z: JOB_MESSAGE_DETAILED: Expanding GroupByKey operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.519Z: JOB_MESSAGE_DEBUG: Annotating graph with Autotuner information.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.562Z: JOB_MESSAGE_DETAILED: Fusing adjacent ParDo, Read, Write, and Flatten operations
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.588Z: JOB_MESSAGE_DETAILED: Fusing consumer TestWriteToCSV/Write/WriteImpl/InitializeWrite into TestWriteToCSV/Write/WriteImpl/DoOnce/Map(decode)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.620Z: JOB_MESSAGE_DETAILED: Fusing consumer TestWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>) into TestWriteToCSV/Write/WriteImpl/DoOnce/Impulse
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.652Z: JOB_MESSAGE_DETAILED: Fusing consumer TestWriteToCSV/Write/WriteImpl/DoOnce/Map(decode) into TestWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.686Z: JOB_MESSAGE_DETAILED: Fusing consumer ReadTwitterData/Read/Map(<lambda at iobase.py:908>) into ReadTwitterData/Read/Impulse
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.709Z: JOB_MESSAGE_DETAILED: Fusing consumer ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/PairWithRestriction into ReadTwitterData/Read/Map(<lambda at iobase.py:908>)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.743Z: JOB_MESSAGE_DETAILED: Fusing consumer ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/SplitWithSizing into ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/PairWithRestriction
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.776Z: JOB_MESSAGE_DETAILED: Fusing consumer ExtractColumns into ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/ProcessElementAndRestrictionWithSizing
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.799Z: JOB_MESSAGE_DETAILED: Fusing consumer Preprocess into ExtractColumns
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.831Z: JOB_MESSAGE_DETAILED: Fusing consumer TestWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn) into Preprocess
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.855Z: JOB_MESSAGE_DETAILED: Fusing consumer TestWriteToCSV/Write/WriteImpl/WriteBundles into TestWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.892Z: JOB_MESSAGE_DETAILED: Fusing consumer TestWriteToCSV/Write/WriteImpl/Pair into TestWriteToCSV/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.921Z: JOB_MESSAGE_DETAILED: Fusing consumer TestWriteToCSV/Write/WriteImpl/GroupByKey/Write into TestWriteToCSV/Write/WriteImpl/Pair
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.945Z: JOB_MESSAGE_DETAILED: Fusing consumer TestWriteToCSV/Write/WriteImpl/Extract into TestWriteToCSV/Write/WriteImpl/GroupByKey/Read
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:33.993Z: JOB_MESSAGE_DEBUG: Workflow config is missing a default resource spec.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:34.026Z: JOB_MESSAGE_DEBUG: Adding StepResource setup and teardown to workflow graph.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:34.059Z: JOB_MESSAGE_DEBUG: Adding workflow start and stop steps.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:34.093Z: JOB_MESSAGE_DEBUG: Assigning stage ids.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:34.236Z: JOB_MESSAGE_DEBUG: Executing wait step start19
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2023-03-19_15_19_28-12573703514186177624 is in state JOB_STATE_RUNNING
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:34.304Z: JOB_MESSAGE_BASIC: Executing operation ReadTwitterData/Read/Impulse+ReadTwitterData/Read/Map(<lambda at iobase.py:908>)+ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/PairWithRestriction+ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/SplitWithSizing
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:34.331Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/DoOnce/Impulse+TestWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)+TestWriteToCSV/Write/WriteImpl/DoOnce/Map(decode)+TestWriteToCSV/Write/WriteImpl/InitializeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:34.344Z: JOB_MESSAGE_DEBUG: Starting worker pool setup.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:19:34.372Z: JOB_MESSAGE_BASIC: Starting 1 workers in europe-west1-b...
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:20:07.967Z: JOB_MESSAGE_DETAILED: Autoscaling: Raised the number of workers to 1 based on the rate of progress in the currently running stage(s).
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:20:53.667Z: JOB_MESSAGE_DETAILED: Workers have started successfully.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:02.988Z: JOB_MESSAGE_DETAILED: All workers have finished the startup processes and began to receive work requests.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:05.568Z: JOB_MESSAGE_BASIC: Finished operation ReadTwitterData/Read/Impulse+ReadTwitterData/Read/Map(<lambda at iobase.py:908>)+ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/PairWithRestriction+ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/SplitWithSizing
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:05.626Z: JOB_MESSAGE_DEBUG: Value "ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7-split-with-sizing-out3" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:08.980Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/DoOnce/Impulse+TestWriteToCSV/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)+TestWriteToCSV/Write/WriteImpl/DoOnce/Map(decode)+TestWriteToCSV/Write/WriteImpl/InitializeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.041Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/DoOnce/Map(decode).None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.074Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/InitializeWrite.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.127Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/WriteBundles/View-python_side_input0-TestWriteToCSV/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.160Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input0-TestWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.174Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/WriteBundles/View-python_side_input0-TestWriteToCSV/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.182Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input0-TestWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.212Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input0-TestWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.225Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/WriteBundles/View-python_side_input0-TestWriteToCSV/Write/WriteImpl/WriteBundles.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.239Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input0-TestWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.270Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input0-TestWriteToCSV/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.291Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:09.313Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input0-TestWriteToCSV/Write/WriteImpl/PreFinalize.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:12.137Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:12.221Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/GroupByKey/Session" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:12.267Z: JOB_MESSAGE_BASIC: Executing operation ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/ProcessElementAndRestrictionWithSizing+ExtractColumns+Preprocess+TestWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn)+TestWriteToCSV/Write/WriteImpl/WriteBundles+TestWriteToCSV/Write/WriteImpl/Pair+TestWriteToCSV/Write/WriteImpl/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:25.887Z: JOB_MESSAGE_BASIC: Finished operation ref_AppliedPTransform_ReadTwitterData-Read-SDFBoundedSourceReader-ParDo-SDFBoundedSourceDoFn-_7/ProcessElementAndRestrictionWithSizing+ExtractColumns+Preprocess+TestWriteToCSV/Write/WriteImpl/WindowInto(WindowIntoFn)+TestWriteToCSV/Write/WriteImpl/WriteBundles+TestWriteToCSV/Write/WriteImpl/Pair+TestWriteToCSV/Write/WriteImpl/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:25.940Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:25.985Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:26.042Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/GroupByKey/Read+TestWriteToCSV/Write/WriteImpl/Extract
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:29.609Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/GroupByKey/Read+TestWriteToCSV/Write/WriteImpl/Extract
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:29.673Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/Extract.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:29.727Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input1-TestWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:29.761Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input1-TestWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:29.773Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input1-TestWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:29.803Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input1-TestWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:29.825Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input1-TestWriteToCSV/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:29.872Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/PreFinalize/View-python_side_input1-TestWriteToCSV/Write/WriteImpl/PreFinalize.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:29.926Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:33.241Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:33.299Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/PreFinalize.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:33.357Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input2-TestWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:33.414Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input2-TestWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:33.469Z: JOB_MESSAGE_DEBUG: Value "TestWriteToCSV/Write/WriteImpl/FinalizeWrite/View-python_side_input2-TestWriteToCSV/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:33.529Z: JOB_MESSAGE_BASIC: Executing operation TestWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:36.881Z: JOB_MESSAGE_BASIC: Finished operation TestWriteToCSV/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:36.938Z: JOB_MESSAGE_DEBUG: Executing success step success17
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:37.004Z: JOB_MESSAGE_DETAILED: Cleaning up.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:37.057Z: JOB_MESSAGE_DEBUG: Starting worker pool teardown.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:25:37.088Z: JOB_MESSAGE_BASIC: Stopping worker pool...
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:26:26.852Z: JOB_MESSAGE_DETAILED: Autoscaling: Resized worker pool from 1 to 0.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:26:26.900Z: JOB_MESSAGE_BASIC: Worker pool stopped.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-03-19T22:26:26.930Z: JOB_MESSAGE_DEBUG: Tearing down pending resources...
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2023-03-19_15_19_28-12573703514186177624 is in state JOB_STATE_DONE

# %% [markdown]
# Omitimos el entrenamiento en la nube para no incurrir en costes innecesarios.

# %% [markdown]
# ### Validación predict en Dataflow
#
# Con el comando mostrado a continuación se valida la predicción correcta de los datos de test usando los modelos generados en el comando anterior.

# %% [markdown]
# Generamos un timestamp para el almacenamiento de las inferencias en Google Cloud Storage.

# %%
from datetime import datetime

# current date and time
TIMESTAMP = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

# %%
# For using sample models: --model-dir gs://$BUCKET_NAME/models/
! python3 predict.py \
  --work-dir $GCP_WORK_DIR \
  --model-dir $GCP_WORK_DIR/model/ \
  batch \
  --project $PROJECT_ID \
  --region $GCP_REGION \
  --runner DataflowRunner \
  --temp_location $GCP_WORK_DIR/beam-temp \
  --setup_file ./setup.py \
  --inputs-dir $GCP_WORK_DIR/transformed_data/test/part* \
  --outputs-dir $GCP_WORK_DIR/predictions/$TIMESTAMP
